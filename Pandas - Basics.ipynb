# %%
import pandas as pd

# %%
## Series
list = ['a','b','c','d','e']

# %%
list[1]
# Out:
# 'b'

# %%
pd.Series(list)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
## Series
list1 = ["umang","ram","Shyam","Python","ml"]  ## data
list2 = ['a','b','c','d','e']  ## index

# %%
list1
# Out:
# ['umang', 'ram', 'Shyam', 'Python', 'ml']

# %%
list2
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
pd.Series(list1,index=list2)
# Out:
# a     umang
# b       ram
# c     Shyam
# d    Python
# e        ml
# dtype: object

# %%
## Series
list1 = ["umang","ram","Shyam","Python","ml","ai"]  ## data
list2 = ['a','b','c','d','e','f']  ## index

# %%
s = pd.Series(list1,index=list2)

# %%
s
# Out:
# a     umang
# b       ram
# c     Shyam
# d    Python
# e        ml
# f        ai
# dtype: object

# %%
s.values
# Out:
# array(['umang', 'ram', 'Shyam', 'Python', 'ml', 'ai'], dtype=object)

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
s.dtype
# Out:
# dtype('O')

# %%
list1 = ['a','b','c','d','e']
list2 = ['f','g','h','i','j']

# %%
list1*list2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-817f9fb5c7cb> in <module>
# ----> 1 list1*list2
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
list1 = ['a','b','c','d','e']
s=pd.Series(list1)
s
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
s*2
# Out:
# 0    aa
# 1    bb
# 2    cc
# 3    dd
# 4    ee
# dtype: object

# %%
list1 = [1,2,3,4,5]
s=pd.Series(list1)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s*2
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
list = ['a','b','c']
list
# Out:
# ['a', 'b', 'c']

# %%
list*3
# Out:
# ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c']

# %%
list = ['a','b','c']
s = pd.Series(list)
s*3
# Out:
# 0    aaa
# 1    bbb
# 2    ccc
# dtype: object

# %%
##############################

# %%
marks = [100,80,90,70,50]
subjects = ["maths","Science","English","SST","Hindi"]
s1 = pd.Series(marks,index=subjects)
s1
# Out:
# maths      100
# Science     80
# English     90
# SST         70
# Hindi       50
# dtype: int64

# %%
marks = [70,90,80,50,30]
subjects = ["maths","Science","English","SST","Hindi"]
s2 = pd.Series(marks,index=subjects)
s2
# Out:
# maths      70
# Science    90
# English    80
# SST        50
# Hindi      30
# dtype: int64

# %%
s1+s2
# Out:
# maths      170
# Science    170
# English    170
# SST        120
# Hindi       80
# dtype: int64

# %%
marks = [100,80,50,20,30]
subjects = ["Science","maths","SST","English","Hindi"]
s3 = pd.Series(marks,index=subjects)
s3
# Out:
# Science    100
# maths       80
# SST         50
# English     20
# Hindi       30
# dtype: int64

# %%
s1
# Out:
# maths      100
# Science     80
# English     90
# SST         70
# Hindi       50
# dtype: int64

# %%
s3
# Out:
# Science    100
# maths       80
# SST         50
# English     20
# Hindi       30
# dtype: int64

# %%
s1+s3
# Out:
# English    110
# Hindi       80
# SST        120
# Science    180
# maths      180
# dtype: int64

# %%
### read from csv file
data = pd.read_csv(r'C:\Users\umang\Desktop\subject.csv',usecols=['marks'],squeeze=True)

# %%
data.head(10)
# Out:
# 0    100
# 1     80
# 2     40
# 3     90
# 4     70
# 5    100
# 6     80
# 7     40
# 8     90
# 9     70
# Name: marks, dtype: int64

# %%
data.tail()
# Out:
# 25      maths
# 26    science
# 27      hindi
# 28    english
# 29        sst
# Name: subjects, dtype: object

# %%
data.sort_values(ascending=True)
# Out:
# 27     40
# 2      40
# 22     40
# 17     40
# 7      40
# 12     40
# 14     70
# 24     70
# 19     70
# 29     70
# 9      70
# 4      70
# 11     80
# 1      80
# 16     80
# 6      80
# 26     80
# 21     80
# 8      90
# 13     90
# 28     90
# 18     90
# 23     90
# 3      90
# 10    100
# 5     100
# 20    100
# 15    100
# 25    100
# 0     100
# Name: marks, dtype: int64

# %%
data[1]
# Out:
# 80

# %%
data[1:10]
# Out:
# 1     80
# 2     40
# 3     90
# 4     70
# 5    100
# 6     80
# 7     40
# 8     90
# 9     70
# Name: marks, dtype: int64

# %%
### read from csv file
data = pd.read_csv(r'C:\Users\umang\Desktop\subject.csv',usecols=['subjects'],squeeze=True)

# %%
data.sort_values(ascending=False).head()
# Out:
# 29    sst
# 24    sst
# 4     sst
# 9     sst
# 19    sst
# Name: subjects, dtype: object

# %% [markdown]
# ##### Data Frames

# %%
### read from csv file
data = pd.read_csv(r'C:\Users\umang\Desktop\subject.csv')

# %%
data
# Out:
#    subjects  marks Grade
# 0     maths    100     A
# 1   science     80     A
# 2     hindi     40     C
# 3   english     90     A
# 4       sst     70     B
# 5     maths    100     A
# 6   science     80     A
# 7     hindi     40     C
# 8   english     90     A
# 9       sst     70     B
# 10    maths    100     A
# 11  science     80     A
# 12    hindi     40     C
# 13  english     90     A
# 14      sst     70     B
# 15    maths    100     A
# 16  science     80     A
# 17    hindi     40     C
# 18  english     90     A
# 19      sst     70     B
# 20    maths    100     A
# 21  science     80     A
# 22    hindi     40     C
# 23  english     90     A
# 24      sst     70     B
# 25    maths    100     A
# 26  science     80     A
# 27    hindi     40     C
# 28  english     90     A
# 29      sst     70     B

# %%
data[['Grade']]
# Out:
#    Grade
# 0      A
# 1      A
# 2      C
# 3      A
# 4      B
# 5      A
# 6      A
# 7      C
# 8      A
# 9      B
# 10     A
# 11     A
# 12     C
# 13     A
# 14     B
# 15     A
# 16     A
# 17     C
# 18     A
# 19     B
# 20     A
# 21     A
# 22     C
# 23     A
# 24     B
# 25     A
# 26     A
# 27     C
# 28     A
# 29     B

# %%
data[['Grade',"marks"]]
# Out:
#    Grade  marks
# 0      A    100
# 1      A     80
# 2      C     40
# 3      A     90
# 4      B     70
# 5      A    100
# 6      A     80
# 7      C     40
# 8      A     90
# 9      B     70
# 10     A    100
# 11     A     80
# 12     C     40
# 13     A     90
# 14     B     70
# 15     A    100
# 16     A     80
# 17     C     40
# 18     A     90
# 19     B     70
# 20     A    100
# 21     A     80
# 22     C     40
# 23     A     90
# 24     B     70
# 25     A    100
# 26     A     80
# 27     C     40
# 28     A     90
# 29     B     70

# %%
data.head()
# Out:
#   subjects  marks Grade
# 0    maths    100     A
# 1  science     80     A
# 2    hindi     40     C
# 3  english     90     A
# 4      sst     70     B

# %%
data['School Name'] = "Delhi Public School"

# %%
data
# Out:
#    subjects  marks Grade          School Name
# 0     maths    100     A  Delhi Public School
# 1   science     80     A  Delhi Public School
# 2     hindi     40     C  Delhi Public School
# 3   english     90     A  Delhi Public School
# 4       sst     70     B  Delhi Public School
# 5     maths    100     A  Delhi Public School
# 6   science     80     A  Delhi Public School
# 7     hindi     40     C  Delhi Public School
# 8   english     90     A  Delhi Public School
# 9       sst     70     B  Delhi Public School
# 10    maths    100     A  Delhi Public School
# 11  science     80     A  Delhi Public School
# 12    hindi     40     C  Delhi Public School
# 13  english     90     A  Delhi Public School
# 14      sst     70     B  Delhi Public School
# 15    maths    100     A  Delhi Public School
# 16  science     80     A  Delhi Public School
# 17    hindi     40     C  Delhi Public School
# 18  english     90     A  Delhi Public School
# ...

# %%
data.drop("Grade",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-f26d37ee4b3b> in <module>
# ----> 1 data.drop("Grade",axis=1,inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
data = data.drop("Grade",axis=1)

# %%
data
# Out:
#    subjects  marks          School Name
# 0     maths    100  Delhi Public School
# 1   science     80  Delhi Public School
# 2     hindi     40  Delhi Public School
# 3   english     90  Delhi Public School
# 4       sst     70  Delhi Public School
# 5     maths    100  Delhi Public School
# 6   science     80  Delhi Public School
# 7     hindi     40  Delhi Public School
# 8   english     90  Delhi Public School
# 9       sst     70  Delhi Public School
# 10    maths    100  Delhi Public School
# 11  science     80  Delhi Public School
# 12    hindi     40  Delhi Public School
# 13  english     90  Delhi Public School
# 14      sst     70  Delhi Public School
# 15    maths    100  Delhi Public School
# 16  science     80  Delhi Public School
# 17    hindi     40  Delhi Public School
# 18  english     90  Delhi Public School
# 19      sst     70  Delhi Public School
# 20    maths    100  Delhi Public School
# 21  science     80  Delhi Public School
# ...

# %%
### read from csv file
data = pd.read_csv(r'C:\Users\umang\Data Science\Data Sets\nba.csv')

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data.isnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# 5    False  False   False     False  False   False   False     True   False
# 6    False  False   False     False  False   False   False    False   False
# 7    False  False   False     False  False   False   False    False   False
# 8    False  False   False     False  False   False   False    False   False
# 9    False  False   False     False  False   False   False    False   False
# 10   False  False   False     False  False   False   False    False   False
# ...

# %%
data.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
mean_salary = data['Salary'].mean()
mean_salary
# Out:
# 4842684.105381166

# %%
data['Salary'].fillna(mean_salary,inplace=True)

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College        Salary
# 0              Texas  7.730337e+06
# 1          Marquette  6.796117e+06
# 2  Boston University  4.842684e+06
# 3      Georgia State  1.148640e+06
# 4                NaN  5.000000e+06

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College        Salary
# 0              Texas  7.730337e+06
# 1          Marquette  6.796117e+06
# 2  Boston University  4.842684e+06
# 3      Georgia State  1.148640e+06
# 4                NaN  5.000000e+06

# %%
data = data.sort_values(ascending=False,by="Salary")

# %%
data.reset_index()
# Out:
#      index                    Name                    Team  Number Position  \
# 0      109             Kobe Bryant      Los Angeles Lakers    24.0       SF
# 1      169            LeBron James     Cleveland Cavaliers    23.0       SF
# 2       33         Carmelo Anthony         New York Knicks     7.0       SF
# 3      251           Dwight Howard         Houston Rockets    12.0        C
# 4      339              Chris Bosh              Miami Heat     1.0       PF
# 5      100              Chris Paul    Los Angeles Clippers     3.0       PG
# 6      414            Kevin Durant   Oklahoma City Thunder    35.0       SF
# 7      164            Derrick Rose           Chicago Bulls     1.0       PG
# 8      349             Dwyane Wade              Miami Heat     3.0       SG
# 9       98          DeAndre Jordan    Los Angeles Clippers     6.0        C
# 10     294       LaMarcus Aldridge       San Antonio Spurs    12.0       PF
# ...

# %%
data.to_csv(r'C:\Users\umang\Desktop\nba.csv',index=True)
